# %%
# 1. Authenticate to azure storage

storage_account_name = "REMOVED"
storage_account_key = "REMOVED"

spark.conf.set(f"fs.azure.account.key.{storage_account_name}.dfs.core.windows.net", storage_account_key)

# 2. Define the gold path
gold_path = f"abfss://gold@{storage_account_name}.dfs.core.windows.net"


# 3. Register managed tables for BI layer

# Sales table
spark.read.format("delta").load(f"{gold_path}/sales_overview").write.mode("overwrite").saveAsTable("gold_sales_overwiew")

# Area stats
spark.read.format("delta").load(f"{gold_path}/area_stats").write.mode("overwrite").saveAsTable("gold_area_stats")

# Supply stats
spark.read.format("delta").load(f"{gold_path}/supply_stats").write.mode("overwrite").saveAsTable("gold_supply_stats")


print("Gold tables are ready for PowerBI usage")
